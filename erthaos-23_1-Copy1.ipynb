# %%
# # Nur bei der Ausführung des Codes in Google Colab verwenden!
# !git clone https://github.com/edadunashvili/KaFk.git

# %%
# # Nur bei der Ausführung des Codes in Google Colab verwenden!
# import os
# try:
#     os.chdir('/content/KaFk')
#     print("Verzeichnis erfolgreich gewechselt!")
# except FileNotFoundError:
#     print("Verzeichnis nicht gefunden.")
# except Exception as e:
#     print(f"Ein Fehler ist aufgetreten: {e}")

# %%
# # Nur bei der Ausführung des Codes in Google Colab verwenden!
# !pip install mglearn

# %%
# # Nur bei der Ausführung des Codes in Google Colab verwenden!
# !pip install --upgrade joblib==1.1.1

# %%
# # Nur bei der Ausführung des Codes in Google Colab verwenden!
# from IPython.display import HTML, display
# def set_css():
#   display(HTML('''
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   '''))
# get_ipython().events.register('pre_run_cell', set_css)

# %% [markdown]
# # erthaos-23

# %% [markdown]
# ### README
#
# #####  Assistent für die automatische Erkennung der gesuchten Motive
#
#
# ##### Anpassbare Variablen:
#
#
# Sprache: Filter für die Sprache des Texte. Entspricht dem Attributwert des Elements //langUsage/anguage/@ident="" in der XML Datei.
#
# gesep_1 ="" , gesep_2 ="" usw.: Die Abfragewerte für das Zielmotiv mit entsprechende Label. Die Werte von 'gesep_1' bis 'gesep_n' können nach der in der Motivliste ausgewälte Zeilen, oder ihre Bestandteilen ausgefült werden und anschließend in der Anfragezeile als Anfrage mit 'or' und/oder 'and' Opperatoren bestimmen.
#
# Stoppwortliste für die bestimmte Sprache.

# %% [markdown]
# ### Trainingsdaten aufbereiten und transformieren

# %%
import xml.etree.ElementTree as ET  #1 Importieren der ElementTree-Bibliothek zum Parsen von XML

#2 XML-Daten laden
tree = ET.parse('Textkorpus.xml')
root_node = tree.getroot()

#3 Namespace definieren
NS = {'tei': 'http://www.tei-c.org/ns/1.0'}

#5 Filtereinstellung für das Attribut `@ident` (kann leer sein)
# filter_ident = ""  # z. B. input("Bitte geben Sie das Attribut 'ident' an (z.B. 'kat'): ").strip()

#6 Variable für die gesammelten Märchendaten
maerchen = ""

#7 Iteration durch die XML-Daten
for corp in root_node.findall(".//tei:teiCorpus", NS):
    if "" in corp.attrib.get("n", "") or "xtk" in corp.attrib.get("n", ""):
        for tei in corp.findall("tei:TEI", NS):
            #8 Filter basierend auf `@ident` oder bei leerem `filter_ident`
#             language = tei.find(".//tei:teiHeader//tei:langUsage/tei:language", NS)
#             if language is not None:
#                 ident_value = language.attrib.get('ident', '')
#                 if filter_ident == "" or ident_value == filter_ident:
                    for ganze in tei.findall(".//tei:text", NS):
                        quelle = ganze.attrib.get('{http://www.w3.org/XML/1998/namespace}id', '')
                        for body in ganze.findall(".//tei:body", NS):
                            for absatz in body.findall(".//tei:p", NS):
                                for phrase in absatz.findall(".//tei:seg", NS):
                                    #9 Labels extrahieren
                                    labela = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/a}ana', 'N/A')
                                    labelb1 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/b1}ana', 'N/A')
                                    labelb2 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/b2}ana', 'N/A')
                                    labelb3 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/b3}ana', 'N/A')
                                    labelb4 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/b4}ana', 'N/A')
                                    labelb5 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/b5}ana', 'N/A')
                                    labelc1 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/c1}ana', 'N/A')
                                    labelc2 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/c2}ana', 'N/A')
                                    labelc3 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/c3}ana', 'N/A')
                                    labelc4 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/c4}ana', 'N/A')
                                    labelc5 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/c5}ana', 'N/A')
                                    labeld = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/d}ana', 'N/A')
                                    inhalt = (phrase.text.lower().strip()
                                              .replace('|', '').replace(':', '').replace("ä", "ae")
                                              .replace("ü", "ue").replace("ö", "oe").replace("ß", "ss")
                                              .replace(",", "").replace("\n", " ").replace("'", "")
                                              .replace("…", "").replace('"', "").replace("*", "")
                                              .replace("(", "").replace(")", "").replace("-", "")
                                              .replace("]", "").replace("[", "").replace(".", "")
                                              .replace("?", "").replace("!", "").replace("„", "")
                                              .replace("+", "").replace("=", "").replace("_", "")
                                              .replace("­", "").replace('“', "").replace('”', "")
                                              .replace(";", "").replace('~', "").replace('`', "")
                                              .replace("«","").replace("»",""))
                                    #10 Bedingung: labela beginnt mit 'a' und labelb1 ist nicht 'N/A'
                                    if labela.startswith('a') and labelb1 != 'N':
                                        #11 Märchendaten sammeln
                                        maerchen += (quelle + ',' + labela + ',' + labelb1 + ',' + labelc1 + ',' +
                                                     labelb2 + ',' + labelc2 + ',' + labelb3 + ',' + labelc3 + ',' +
                                                     labelb4 + ',' + labelc4 + ',' + labelb5 + ',' + labelc5 + ',' +
                                                     labeld + ',' + inhalt + ',0' + '\n')

#12 Ergebnisse in eine CSV-Datei schreiben
with open("text.csv", 'w', encoding='utf-8') as f:
    #13 Kopfzeile schreiben
    f.write('quelle,labela,labelb1,labelc1,labelb2,labelc2,labelb3,labelc3,labelb4,labelc4,labelb5,labelc5,labeld,inhalt,index_binar')
    f.write('\n')
    #14 Gesammelte Märchendaten schreiben
    f.write(maerchen)

print(f"Die Märchendaten wurden in 'text.csv' gespeichert.")
# Out:
# Die Märchendaten wurden in 'text.csv' gespeichert.

# %%
#15 leere Zeichenfolge, die später mit den gewünschten Daten gefüllt werden
abcd1="" 
abcd2="" 
abcd3=""  
abcd4=""  
abcd5=""  

import pandas as pd  
from collections import Counter

#16 Lesen der CSV-Datei und Laden der Daten in ein Pandas DataFrame
df = pd.read_csv('text.csv',  encoding='utf-8')

#17.1 Hinzufügen von Daten zu den entsprechenden Variablen abcd1 bis abcd5
#17.2 Hier werden die Daten aus verschiedenen Spalten des DataFrame kombiniert
abcd1 += df.quelle+','+df.labela+':'+df.labelb1+':'+df.labelc1+':'+df.labeld+':'+','+df.inhalt+',0'
abcd2 += df.quelle+','+df.labela+':'+df.labelb2+':'+df.labelc2+':'+df.labeld+':'+','+df.inhalt+',0'
abcd3 += df.quelle+','+df.labela+':'+df.labelb3+':'+df.labelc3+':'+df.labeld+':'+','+df.inhalt+',0'
abcd4 += df.quelle+','+df.labela+':'+df.labelb4+':'+df.labelc4+':'+df.labeld+':'+','+df.inhalt+',0'
abcd5 += df.quelle+','+df.labela+':'+df.labelb5+':'+df.labelc5+':'+df.labeld+':'+','+df.inhalt+',0'

#18 Zusammenführen der Daten aus den Variablen abcd1 bis abcd5
recorded=(abcd1+'\n'+abcd2+'\n'+abcd3+'\n'+abcd4+'\n'+abcd5+'\n')

#19 Schreiben der kombinierten Daten in eine neue CSV-Datei
with open("text_aw.csv", 'w', encoding='utf-8') as w:
    #20 Schreiben der Kopfzeile
    w.write('quelle,index_string,inhalt,index_binar\n')
    #21 Schreiben der vordefinierten Zeile mit Dummy-Daten
    w.write('000:ballast,ballast,ballast,0\n')
    #22 Schreiben der kombinierten Daten
    w.write("".join(recorded))
    #23 Schließen der Datei
    w.close()

# %%
import csv  

mom=[]  #24 Eine leere Liste zum Speichern der Zeilen, die bestimmten Kriterien entsprechen

#25 Lesen der CSV-Datei 'text_aw.csv'
with open('text_aw.csv', 'r', encoding='utf-8') as f:
    reader = csv.reader(f) 
    #26 Iteration über jede Zeile in der CSV-Datei
    for line in reader:
        #27 Überprüfen, ob die Zeile nicht das Muster ':N:' in der zweiten Spalte enthält
        if ':N:' not in line[1]:
            #28 Wenn das Muster nicht vorhanden ist, wird die Zeile der Liste 'mom' hinzugefügt
            mom.append(line)

#29 Kopieren der Datei text_ax.txt
import shutil, os
with open ('text_ax.txt', 'wt', encoding='utf-8') as f:
    writer = csv.writer(f, delimiter=',')
    writer.writerow(mom)

#30 Öffnen der Datei text_ax.txt zum Lesen
with open('text_ax.txt', 'r', encoding='utf-8') as file:
    #31 Lesen des gesamten Inhalts der Datei
    filedata = file.read()

#32 Bearbeiten des Dateiinhalts, um das gewünschte Format zu erzielen
filedata = (filedata.replace(']","[', "\n").replace('"[','').replace(']"','')
            .replace(" '","").replace("'",""))

#33 Schreiben des bearbeiteten Inhalts in eine neue CSV-Datei text_ay.csv
with open('text_ay.csv', 'w', encoding='utf-8') as file:
    file.write(filedata)

# %%
custom_stop_word_list=[]  #34 Eine leere Liste, um benutzerdefinierte Stoppwörter zu speichern

import nltk
nltk.download('stopwords')  #35 Herunterladen der Stoppwortliste aus der NLTK-Datenbank

from nltk.corpus import stopwords  #36 Importieren der Stoppwortliste aus NLTK
NLTK_stop_words_list=stopwords.words('german')  #37 Laden der Stoppwortliste für die bestimmte Sprache
stpw = custom_stop_word_list + NLTK_stop_words_list
# Out:
# [nltk_data] Error loading stopwords: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>

# %%
#38 Funktion zur Filterung eines CSV-Datensatzes und Zusammenführung mehrfacher Inhalte in eine Zeile
def filter_csv(input_file, output_file):
    data_to_write = []  #39 Liste zum Speichern der zu schreibenden Daten
    with open(input_file, 'r', encoding="utf-8", newline='') as csvfile:  #40 Öffnen der Eingabedatei im Lesemodus
        reader = csv.reader(csvfile)  #41 Erstellen eines CSV-Lesers
        data = list(reader)  #42 Lesen aller Daten in eine Liste
        processed_values = {}  #43 Dictionary zur Nachverfolgung bereits verarbeiteter Inhalte und deren aggregierten Inhalte
        
        for row in data:  #44 Iteration über jede Zeile der Daten
            if len(row) < 4:  #45 Sicherstellen, dass die Zeile genügend Spalten hat
                continue  #46 Zeile überspringen, wenn sie nicht genügend Spalten hat
            content_key = row[2]  #47 Inhalt aus Spalte 3 als Schlüssel verwenden
            if content_key not in processed_values:  #48 Überprüfen, ob der Inhalt noch nicht verarbeitet wurde
                processed_values[content_key] = row  #49 Zeile als verarbeitet markieren und speichern
            else:
                #50 Ergänzen des Inhalts in Spalte 2 der bereits gespeicherten Zeile
                processed_values[content_key][1] += ' ' + row[1]
        
    data_to_write = list(processed_values.values())  #51 Alle verarbeiteten Zeilen in eine Liste umwandeln
    
    with open(output_file, 'w', encoding="utf-8", newline='') as csvfile:  #52 Öffnen der Ausgabedatei im Schreibmodus
        csvfile.write('\n')  #53 Neue Zeile nach der Header-Zeile
        writer = csv.writer(csvfile)  #54 Erstellen eines CSV-Schreibers
        writer.writerows(data_to_write)  #55 Schreiben der gefilterten Daten

#56 Beispielaufruf der Funktion:
filter_csv('text_ay.csv', 'text_az.csv')

# %%
from collections import Counter

#57 Lesen der CSV-Datei 'text_ay.csv' und Laden der Daten in ein Pandas DataFrame
df = pd.read_csv('text_az.csv',  encoding='utf-8')
#58 Zählen der Vorkommen jeder Zeichenfolge in der Spalte 'index_string'
indexliste = Counter(df.index_string)
#59 Ausgabe der einzigartigen Zeichenfolgen in der Spalte 'index_string'
print(*indexliste, sep='\n')
# Out:
# ballast
# a551:h:KRANKHEIT:rHH:
# a551:F:Zu_Beauftragungen_anregen:rHH_rVB:
# a551:F:HEILMITTEL_besorgen:rHH_fHD:
# a551:f:VERLOCKUNG:fHD_fVB: a551:h:Auf_VERLOCKUNG_reagieren:fHD_fVB: a551:h:FREIHEITSBERAUBUNG:fHD_fVB:
# a551:F:Um_einen_Auftrag_WERBEN:rHD_rHH: a551:Hh:Auf_WERBEN_reagieren:rHD_rHH:
# a551:f:VERLOCKUNG:rHD_fVB: a551:H:Auf_VERLOCKUNG_reagieren:rHD_fVB:
# a551:H:Potenziellen_Feind_zum_Gastgeber_gewinnen:rHD_rST: a551:H:REITTIER_erhalten:rHD_rST: a551:Hh:Weiterverweisung_an_anderen_Stifter_oder_Helfer:rHD_rST:
# a551:H:Potenziellen_Feind_zum_Gastgeber_gewinnen:rHD_rST: a551:H:REITTIER_erhalten:rHD_rST: a551:HF:Weiterverweisung_an_anderen_Stifter_oder_Helfer:rHD_rST:
# a551:H:Potenziellen_Feind_zum_Gastgeber_gewinnen:rHD_rST: a551:H:REITTIER_erhalten:rHD_rST: a551:HF:HEILMITTEL_erfassen:rHD_rST:
# a551:Hh:Beiwohnung_mit_der_Schönen:rHD_rBZ_rZO: a551:F:MARKIERUNGEN_anbringen:rHD_rBZ_rZO: a551:H:HEILMITTEL_erfassen:rHD_rBZ_rZO: a551:h:KONTAKT_abbrechen:rHD_rBZ_rZO:
# a551:H:PFÖRTNER_entkommen:rHD_fHF:
# a551:F:Auf_Hilfsquelle_zurückgreifen:rHD_rST_rZM: a551:H:Universellen_ZAUBERMITTEL_erhalten:rHD_rST_rZM:
# a551:F:Auf_Hilfsquelle_zurückgreifen:rHD_rST_rZM: a551:H:REITTIER_erhalten:rHD_rST_rZM: a551:HF:Im_STICH_gelassen_zu_werden_beheben:rHD_rST_rZM:
# a551:Hh:Auf_Warnung_im_STICH_gelassen_zu_werden_reagieren:rHD: a551:Hh:Sorge_um_Freikaufsbedürftige:rHD:
# a551:f:TÖTUNG:rZO_fHD: a551:h:ANEIGNUNG:rZO_fHD:
# a551:f:TODESAUFTRAG:rHD_rVB_fHD: a551:H:TODESAUFTRAG_entkommen:rHD_rVB_fHD: a551:h:VERBANNUNG:rHD_rVB_fHD: a551:H:SCHWEIGEPFLICHT_verhängen:rHD_rVB_fHD:
# a551:Hh:HEILMITTEL_besorgen:rHH_rZO_fHD: a551:h:KRANKHEIT_beheben:rHH_rZO_fHD:
# a551:H:MARKIERUNGEN_erkennen:rBZ: a551:F:KONTAKT_wiederherstellen:rBZ:
# a551:F:IDENTITÄT_beweisen:rHH_rBZ:
# a551:F:IDENTITÄT_beweisen:rBZ_fHD: a551:h:IDENTITÄT_beweisen:rBZ_fHD:
# a551:H:SCHWEIGEPFLICHT_beheben:rHD_rVB_fHD:
# a551:H:KRANKHEIT_beheben:rHD_rHH_rZO:
# a551:H:IDENTITÄT_beweisen:rHD_rBZ: a551:H:KONTAKT_wiederherstellen:rHD_rBZ:
# a551:H:Heiraten:rHD_rHH_rBZ:
# a551:H:Bestrafung:fHD:
# a551:F:SELTENEN_Gegenstand_besorgen:rHH_rVB:
# a551:F:Um_einen_Auftrag_WERBEN:rHH_fHD: a551:F:Beschaffung_der_AUSRÜSTUNG:rHH_fHD:
# a551:H:Beschaffung_der_AUSRÜSTUNG:rZM_fHD: a551:Ff:Wegweisung_mit_ALTERNATIVEN:rZM_fHD:
# a551:Hh:FEHLENDEN_Gegenstand_erfassen:rAN_fZO:
# a551:h:SELTENEN_Gegenstand_besorgen:rHH_fHD: a551:h:FREIHEITSBERAUBUNG:rHH_fHD:
# a551:F:Um_einen_Auftrag_WERBEN:rHH_fHD:
# a551:Ff:Wegweisung_mit_ALTERNATIVEN:rZM_fHD: a551:Hh:Auf_ALTERNATIVEN_reagieren:rZM_fHD:
# a551:f:Gastfreundlichkeit_VORTÄUSCHEN:rAN_fHD: a551:h:Auf_VORTÄUSCHEN_reagieren:rAN_fHD: a551:h:FREIHEITSBERAUBUNG:rAN_fHD:
# a551:F:Um_einen_Auftrag_WERBEN:rHD_rHH: a551:Hh:Auf_WERBEN_reagieren:rHD_rHH: a551:F:Beschaffung_der_AUSRÜSTUNG:rHD_rHH:
# a551:Hh:Beschaffung_der_AUSRÜSTUNG:rHD:
# a551:H:REITTIER_erhalten:rHD:
# a551:Ff:Wegweisung_mit_ALTERNATIVEN:rHD_rZM: a551:Hh:Auf_ALTERNATIVEN_reagieren:rHD_rZM:
# a551:H:Potenziellen_Feind_zum_Gastgeber_gewinnen:rHD_rST: a551:HF:Weiterverweisung_an_anderen_Stifter_oder_Helfer:rHD_rST: a551:H:REITTIER_erhalten:rHD_rST:
# a551:H:Potenziellen_Feind_zum_Gastgeber_gewinnen:rHD_rST: a551:HF:SELTENEN_Gegenstand_erfassen:rHD_rST: a551:H:Richtiges_auswählen:rHD_rST:
# a551:H:Richtiges_auswählen:rHD_rBZ_rZO: a551:Hh:Beiwohnung_mit_der_Schönen:rHD_rBZ_rZO: a551:F:MARKIERUNGEN_anbringen:rHD_rBZ_rZO: a551:h:KONTAKT_abbrechen:rHD_rBZ_rZO:
# a551:H:SELTENEN_Gegenstand_erfassen:rHD_rZO: a551:H:Universellen_ZAUBERMITTEL_erfassen:rHD_rZO:
# a551:h:PFÖRTNER_entkommen:rHD_rBZ_fHF:
# a551:H:FLUCHT:rHD_rST:
# a551:F:VERFOLGUNG_stören:rST_rBZ:
# a551:F:FLUCHT:rHD_rST:
# a551:H:VERFOLGUNG_stören:rST_rBZ:
# a551:H:VERFOLGUNG_entkommen:rHD_rBZ:
# a551:F:VERMISSEN_der_Angehörige_beheben:rHD_rAN: a551:f:Gastfreundlichkeit_VORTÄUSCHEN:rHD_rAN: a551:H:Auf_VORTÄUSCHEN_reagieren:rHD_rAN: a551:H:FREIHEITSBERAUBUNG_beheben:rHD_rAN:
# a551:H:VERMISSEN_der_Angehörige_beheben:rHD_fHD:
# a551:h:SCHLAF:rHD:
# a551:h:ANEIGNUNG:rZO_fHD:
# a551:h:Sich_ZURÜCKZIEHEN:rHD:
# a551:F:MARKIERUNGEN_erkennen:rHH_rVB_rBZ: a551:F:KONTAKT_wiederherstellen:rHH_rVB_rBZ:
# a551:h:IDENTITÄT_beweisen:rBZ_fHD: a551:h:Bestrafung:rBZ_fHD:
# a551:F:KONTAKT_wiederherstellen:rHH_rBZ: a551:F:IDENTITÄT_beweisen:rHH_rBZ:
# a551:F:ZURÜCKZIEHEN_beheben:rHH_rVB:
# a551:H:Wechsel_der_IDENTITÄT_eingestehen:rHD_rHH_rVB: a551:H:ZURÜCKZIEHEN_beheben:rHD_rHH_rVB:
# a551:F:IDENTITÄT_beweisen:rHD_rBZ: a551:H:IDENTITÄT_beweisen:rHD_rBZ:
# a551:f:VERLOCKUNG:fHD: a551:h:Auf_VERLOCKUNG_reagieren:fHD:
# a551:H:Potenziellen_Feind_zum_Gastgeber_gewinnen:rHD_rST: a551:H:Hilfeversprechen_erhalten:rHD_rST:
# a551:h:Wegweisung_erhalten:rHD_rST: a551:HF:Weiterverweisung_an_anderen_Stifter_oder_Helfer:rHD_rST:
# a551:Hh:Weiterverweisung_an_anderen_Stifter_oder_Helfer:rHD_rST_rZM: a551:H:Flugzeugendes_ZAUBERMITTEL_erhalten:rHD_rST_rZM:
# a551:H:Komplikationsfreier_Flug:rHD_rZM:
# a551:HF:Wegweisung_erhalten:rHD_rHF_rST:
# a551:HF:HEILMITTEL_erfassen:rHD_rHF: a551:hf:TABU_Frist_nicht_überziehen:rHD_rHF:
# a551:H:HEILMITTEL_erfassen:rHD_rBZ_rZO: a551:H:Beiwohnung_mit_der_Schönen:rHD_rBZ_rZO: a551:F:MARKIERUNGEN_anbringen:rHD_rBZ_rZO: a551:h:KONTAKT_abbrechen:rHD_rBZ_rZO:
# a551:Hh:ANGST_mit_ANGST_vergelten:rHD_rHF: a551:Hh:ANGST_mit_ANGST_vergelten:rHD_rHF: a551:Hh:ANGST_mit_ANGST_vergelten:rHD_rHF:
# a551:H:Auf_Hilfsquelle_zurückgreifen:rHD_rST_rZM: a551:H:Flugzeugendes_ZAUBERMITTEL_erhalten:rHD_rST_rZM:
# a551:H:Auf_Hilfsquelle_zurückgreifen:rHD_rST_rZM: a551:H:Proviantproduzierenden_ZAUBERMITTEL_erhalten:rHD_rST_rZM:
# a551:H:Auf_Hilfsquelle_zurückgreifen:rHD_rST_rZM: a551:H:WAFFE_oder_ZAUBERMITTEL_erhalten:rHD_rST_rZM:
# a551:h:SCHLAF:rZO_fHD: a551:h:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_austauschen:rZO_fHD:
# a551:Hh:HEILMITTEL_besorgen:rHD_rHH_fZO: a551:h:KRANKHEIT_beheben:rHD_rHH_fZO:
# a551:H:HEILMITTEL_besorgen:rHH_rZO_fHD: a551:H:KRANKHEIT_beheben:rHH_rZO_fHD:
# a551:f:TODESAUFTRAG:rHD_rHH:
# a551:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rZM:
# a551:H:TODESAUFTRAG_entkommen:rHD_rHH_rVB:
# a551:h:RESPEKTLOSIGKEIT:rHD_fHD:
# a551:F:HEILMITTEL_besorgen:rVB:
# a551:F:Um_einen_Auftrag_WERBEN:rHD_rHH:
# a551:F:Sorge_um_Hilfsbedürftige:rHD_fST: a551:H:Sorge_um_Hilfsbedürftige:rHD_fST: a551:HF:PFÖRTNER_besänftigen:rHD_fST: a551:HF:HEILMITTEL_erfassen:rHD_fST: a551:HF:TABU_Frist_nicht_überziehen:rHD_fST:
# a551:H:PFÖRTNER_besänftigen:rHD_fHF:
# a551:H:HEILMITTEL_erfassen:rHD_rBZ_rZO: a551:H:Auf_TABU_reagieren:rHD_rBZ_rZO: a551:h:KONTAKT_abbrechen:rHD_rBZ_rZO:
# a551:F:Sorge_um_Freikaufsbedürftige:rHD_fHD: a551:H:Sorge_um_Freikaufsbedürftige:rHD_fHD:
# a551:f:Sich_ZURÜCKZIEHEN:rHD:
# a551:F:KONTAKT_wiederherstellen:rHD_rBZ: a551:F:ZURÜCKZIEHEN_beheben:rHD_rBZ: a551:H:Held_erkennen:rHD_rBZ: a551:H:Heiraten:rHD_rBZ:
# a590:h:Kinderlosigkeit:rHH:
# a590:H:Wundermittel_zur_EMPFÄNGNIS_erhalten:rHH_rAN:
# a590:H:Wunderbare_EMPFÄNGNIS:rHD_rHF: a590:H:Zur_Welt_kommen:rHD_rHF:
# a590:h:KONTAKT_abbrechen:rHH_fHH:
# a590:h:GEHEIME_LIEBESBEZIEHUNG:rAN_fHH:
# a590:f:Ungewünschtes_Wesen_beseitigen:rAN_fHH: a590:h:VERGIFTUNG:rAN_fHH:
# a590:F:Auf_Hilfsquelle_zurückgreifen:rHD_rHF: a590:HF:VERGIFTUNG_beheben:rHD_rHF:
# a590:H:VERGIFTUNG_beheben:rHD_fHH:
# a590:h:VERGIFTUNG:fHH:
# a590:F:Auf_Hilfsquelle_zurückgreifen:rHD_rHF: a590:H:VERGIFTUNG_beheben:rHD_rHF:
# a590:f:Ungewünschtes_Wesen_beseitigen:rAN_fHH: a590:f:Krankheit_VORTÄUSCHEN:rAN_fHH:
# a590:F:KRANKHEIT_beheben:rHH_rST: a590:h:KRANKHEIT_beheben:rHH_rST:
# a590:f:Zu_Beauftragungen_anregen:rAN_fHH: a590:f:TODESAUFTRAG:rAN_fHH:
# a590:F:Auf_Hilfsquelle_zurückgreifen:rHD_rHF: a590:HF:TODESAUFTRAG_entkommen:rHD_rHF:
# a590:F:Beschaffung_der_AUSRÜSTUNG:rHD_fHH:
# a590:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_ausprobieren:rHD_rHF_fHH: a590:F:Beschaffung_der_AUSRÜSTUNG:rHD_rHF_fHH: a590:H:FLUCHT:rHD_rHF_fHH:
# a590:f:IDENTITÄT_ändern:rHD_rHF:
# a314:F:VEREINBARUNG:rHD_rHP:
# a314:f:Liebe_wird_ausgelöst:rHD_rPP:
# a314:F:HEIRATSABSICHT_kundtun:rHP_fPP: a314:H:Auf_HEIRATSABSICHT_reagieren:rHP_fPP:
# a314:F:HEIRATSABSICHT_kundtun:rHP_rPP: a314:H:Auf_HEIRATSABSICHT_reagieren:rHP_rPP:
# a314:f:Um_einen_Mann_WERBEN:rHP:
# a314:f:Um_einen_Mann_WERBEN:fPP:
# a314:Ff:Um_einen_Mann_WERBEN:rHP_rPP: a314:f:RESPEKTLOSIGKEIT:rHP_rPP:
# a314:h:KRANKHEIT:rHH_rVB: a314:F:HEILMITTEL_besorgen:rHH_rVB:
# a314:F:Beschaffung_der_AUSRÜSTUNG:fHD:
# a314:F:Um_einen_Auftrag_WERBEN:rHP_rPP:
# a314:Hh:Beschaffung_der_AUSRÜSTUNG:rHD_fHD_fZM: a314:h:RESPEKTLOSIGKEIT:rHD_fHD_fZM:
# a314:F:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rHF_rZO: a314:H:IDENTITÄT_ändern:rHD_rHF_rZO: a314:H:HEILMITTEL_erfassen:rHD_rHF_rZO:
# a314:F:MARKIERUNGEN_anbringen:rHD_fHD:
# a314:f:IDENTITÄT_ändern:rHD_fHD:
# a314:h:KRANKHEIT_beheben:rHP_fHD:
# a314:F:HEILMITTEL_besorgen:rHD_rPP:
# a314:F:Vermittlung:rHP_rPP:
# a314:H:KRANKHEIT_beheben:rHD_rHP:
# a314:F:Auf_Hilfsquelle_zurückgreifen:rHD_rHF_rHP: a314:F:IDENTITÄT_ändern:rHD_rHF_rHP: a314:F:Held_erkennen:rHD_rHF_rHP:
# a314:H:MARKIERUNGEN_erkennen:rHP_fHD: a314:H:Bestrafung:rHP_fHD:
# a551:F:VOGEL_erfassen:rHD_rHH_fHD: a551:F:VEREINBARUNG:rHD_rHH_fHD:
# a551:Hh:Beschaffung_der_AUSRÜSTUNG:rHD_fHD_fZM: a551:h:RESPEKTLOSIGKEIT:rHD_fHD_fZM:
# a551:F:Gutes_Benehmen:rHD_rST: a551:H:Gutes_Benehmen:rHD_rST: a551:HF:Weiterverweisung_an_anderen_Stifter_oder_Helfer:rHD_rST: a551:F:HEILMITTEL_besorgen:rHD_rST:
# a551:HF:Weiterverweisung_an_anderen_Stifter_oder_Helfer:rHD_rST: a551:F:HEILMITTEL_besorgen:rHD_rST:
# a551:H:Potenziellen_Feind_zum_Gastgeber_gewinnen:rHD_rST: a551:HF:HEILMITTEL_erfassen:rHD_rST: a551:HF:VOGEL_erfassen:rHD_rST: a551:hf:TABU_Sonstiges:rHD_rST: a551:H:Universellen_ZAUBERMITTEL_erhalten:rHD_rST:
# a551:H:VOGEL_erfassen:rHD_rZO: a551:H:HEILMITTEL_erfassen:rHD_rZO: a551:h:Auf_TABU_reagieren:rHD_rZO:
# a313:H:FLUCHT:rHD_rZM_rBZ: a313:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rZM_rBZ:
# a551:H:HEILMITTEL_besorgen:rHD_rST:
# a551:h:SCHWEIGEPFLICHT_verhängen:rHD_rZO_fHD: a551:h:ANEIGNUNG:rHD_rZO_fHD: a551:h:IDENTITÄT_ändern:rHD_rZO_fHD:
# a551:H:HEILMITTEL_besorgen:rHH_rZO_fHD: a551:H:KRANKHEIT_beheben:rHH_rZO_fHD: a551:h:VEREINBARUNG_einhalten:rHH_rZO_fHD:
# a551:h:IDENTITÄT_beweisen:rBZ_fHD:
# a551:F:WETTKAMPF:rHH_rBZ:
# a551:H:IDENTITÄT_beweisen:rHD_rHH_rBZ: a551:H:KONTAKT_wiederherstellen:rHD_rHH_rBZ:
# a551:F:Zu_Beauftragungen_anregen:rHH_rST:
# a551:F:HEILMITTEL_besorgen:rHD_rHH_fHD: a551:F:VEREINBARUNG:rHD_rHH_fHD:
# a551:HF:HEILMITTEL_erfassen:rHD_rST_fHD:
# a551:h:Sich_abseilen_LASSEN:rHD_fHD: a551:h:Sich_abseilen_LASSEN:rHD_fHD: a551:H:Sich_abseilen_LASSEN:rHD_fHD:
# a551:H:HEILMITTEL_erfassen:rHD_rZO:
# a551:H:Sich_oder_Andere_hochziehen_LASSEN:rHD_fHD:
# a551:H:Auf_dem_Heimweg:rHD_rZO_fHD:
# a551:h:MEINEID_erpressen:fHD:
# a551:h:TÖTUNG:rHD_rZO_fHD: a551:h:ANEIGNUNG:rHD_rZO_fHD:
# a780:H:Änderung_der_EXISTENZFORM:rVB_rZM: a780:F:Enthüllung_der_Wahrheit_durch_das_subtile_Mittel:rVB_rZM:
# a780:H:Enthüllung_der_Wahrheit_durch_das_subtile_Mittel:rHH_rZM:
# a780:H:Enthüllung_der_Wahrheit_durch_das_subtile_Mittel:rZO_fHD: a780:H:MEINEID_erpressen_beheben:rZO_fHD:
# a780:H:Bestrafung:rHH_fHD:
# a301:h:VERLUST_von_Tieren_Früchten_Ernte_Essen_Futter_usw:rHH:
# a301:F:Um_einen_Auftrag_WERBEN:rHH_fHD:
# a301:h:Wache_halten:rHH_fHD:
# a301:h:Vorgang_deuten:rHD_rHH_fHD:
# a301:h:Wache_halten:fHD:
# a301:h:Vorgang_deuten:rHH_fHD:
# a301:F:Um_einen_Auftrag_WERBEN:rHD_rHH:
# a301:H:Wegweisung_erpressen:rHD_rAN:
# a301:H:Vorgang_deuten:rHD_rHH_fHD:
# a301:h:Sich_abseilen_LASSEN:rHD_fHD: a301:H:Sich_abseilen_LASSEN:rHD_fHD:
# a301:HF:Abraten_von_der_MISSION:rHD_rPP: a301:h:Auf_ABRATEN_von_der_Mission_reagieren:rHD_rPP: a301:HF:Zweikampf:rHD_rPP:
# a301:H:Zweikampf:rHD_rAN:
# a301:F:Krisenursachen_ergründen:rHD_rPP:
# a301:Hh:Sich_oder_Andere_hochziehen_LASSEN:rHD_rPP_fHD: a301:Hh:Sich_oder_andere_tragen_LASSEN:rHD_rPP_fHD: a301:Hh:Sich_oder_andere_tragen_LASSEN:rHD_rPP_fHD: a301:h:Sich_oder_Andere_hochziehen_LASSEN:rHD_rPP_fHD: a301:h:Jemanden_im_STICH_lassen:rHD_rPP_fHD:
# a301:H:REITTIER_erhalten:rHD_rHF:
# a301:h:Vorgang_deuten:rHH_fHD: a301:h:VERMISSEN_der_Angehörige:rHH_fHD:
# a551:F:Zu_Beauftragungen_anregen:rHD_rVB:
# a551:h:HEILMITTEL_besorgen:fHD:
# a551:F:Krisenursachen_ergründen:rHD_rHF: a551:HF:PFÖRTNER_besänftigen:rHD_rHF: a551:HF:HEILMITTEL_erfassen:rHD_rHF: a551:HF:FLUCHT_vorbereiten:rHD_rHF:
# a551:H:PFÖRTNER_besänftigen:rHD_rHF:
# a551:H:BESITZER_DES_OBJEKTES_erfassen:rHD_rBZ_rZO: a551:F:MARKIERUNGEN_anbringen:rHD_rBZ_rZO: a551:h:KONTAKT_abbrechen:rHD_rBZ_rZO: a551:H:HEILMITTEL_erfassen:rHD_rBZ_rZO: a551:H:Zauberkunst_erlernen:rHD_rBZ_rZO:
# a551:f:VERFOLGUNG:rHD_rZM_rBZ: a551:H:FLUCHT:rHD_rZM_rBZ: a551:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rZM_rBZ: a551:H:VERFOLGUNG_entkommen:rHD_rZM_rBZ:
# a551:H:Begegnung:rHD_rHF:
# a551:h:ANEIGNUNG:rHD_rZO_fHD:
# a551:H:HEILMITTEL_besorgen:rZO_fHD: a551:H:KRANKHEIT_beheben:rZO_fHD:
# a551:h:Sich_ZURÜCKZIEHEN:rHD_rHF:
# a551:H:ZURÜCKZIEHEN_beheben:rHD_rHF_fHD: a551:h:FREIHEITSBERAUBUNG:rHD_rHF_fHD:
# a551:HF:Erlösung:rHD_rHF: a551:H:Erlösung:rHD_rHF:
# a551:H:Bestrafung:rHD_fHD:
# a551:H:VERMISSEN_der_Angehörige_beheben:rHD_rHH:
# a551:H:KONTAKT_wiederherstellen:rHD_rBZ: a551:H:Heiraten:rHD_rBZ:
# a303:F:TABU_Sonstiges:rHH:
# a303:H:Wunderbare_EMPFÄNGNIS:rHD: a303:H:Zur_Welt_kommen:rHD:
# a303:H:Beschaffung_der_AUSRÜSTUNG:rHD_rHH:
# a554:H:Potenzielle_Beute_begnadigen:rHD_rHF: a554:H:Begleiter_gewinnen:rHD_rHF:
# a303:F:MARKIERUNGEN_anbringen:rHD_rZM: a303:h:KONTAKT_abbrechen:rHD_rZM:
# a300:F:Menschliche_OPFERGABE_beheben:rHD: a300:F:VEREINBARUNG:rHD:
# a300:H:Zweikampf:rHD: a300:F:MARKIERUNGEN_anbringen:rHD: a300:h:SCHLAF:rHD:
# a300:h:TÖTUNG:rHD_fHD: a300:h:MARKIERUNGEN_anbringen:rHD_fHD:
# a300:h:VEREINBARUNG_einhalten:rHP_fHD: a300:h:MARKIERUNGEN_vorlegen:rHP_fHD:
# a300:F:WIEDERBELEBEN:rHD_rHF:
# a300:F:ZWANGSEHE_Drohung:rHD_rVB:
# a300:H:KONTAKT_wiederherstellen:rHD_rPP_fHD: a300:H:MARKIERUNGEN_erkennen:rHD_rPP_fHD: a300:H:Held_erkennen:rHD_rPP_fHD: a300:H:Bestrafung:rHD_rPP_fHD: a300:H:Heiraten:rHD_rPP_fHD:
# a303:h:Sich_auf_Eindringlinge_einlassen:rHD_rAN: a303:h:VERSTEINERUNG:rHD_rAN:
# a303:H:MARKIERUNGEN_erkennen:rHD_rZM:
# a303:F:IDENTITÄT_ändern:rHD_rAN: a303:h:Geänderte_IDENTITÄT_VORTÄUSCHEN:rHD_rAN:
# a303:H:Wiedergutmachung_erzielen:rHD_rAN: a303:H:VERSTEINERUNG_beheben:rHD_rAN:
# a303:H:Wundermittel_zur_EMPFÄNGNIS_erhalten:rHH_rST:
# a303:H:Wunderbare_EMPFÄNGNIS:rHD_rHF: a303:H:Zur_Welt_kommen:rHD_rHF:
# a303:F:MARKIERUNGEN_anbringen:rHD_rZM:
# a300:F:Menschliche_OPFERGABE_beheben:rHD_rVB:
# a300:H:Zweikampf:rHD_rPP_rAN: a300:F:MARKIERUNGEN_anbringen:rHD_rPP_rAN: a300:h:KONTAKT_abbrechen:rHD_rPP_rAN:
# a300:h:MEINEID_erpressen:rHP_rPP_fHD: a300:h:Heldentat_VORTÄUSCHEN:rHP_rPP_fHD: a300:h:VEREINBARUNG_einhalten:rHP_rPP_fHD: a300:F:Hochzeit_verschieben:rHP_rPP_fHD:
# a300:H:Zweikampf:rHD_rHF_rAN: a300:H:Menschliche_OPFERGABE_beheben:rHD_rHF_rAN: a300:h:KONTAKT_abbrechen:rHD_rHF_rAN:
# a300:h:SCHLAF:rHD_rPP_fHD: a300:h:TÖTUNG:rHD_rPP_fHD: a300:h:SCHWEIGEPFLICHT_verhängen:rHD_rPP_fHD:
# a300:H:WIEDERBELEBEN_angehen:rHD_rHF: a300:Hh:WIEDERBELEBEN:rHD_rHF: a300:H:WIEDERBELEBEN:rHD_rHF:
# a300:F:NEUGIER_auslösen:rHD_rHF:
# a300:H:Auf_ausgelöste_NEUGIER_reagieren:rHD_rPP_rAN: a300:H:KONTAKT_wiederherstellen:rHD_rPP_rAN: a300:H:Held_erkennen:rHD_rPP_rAN: a300:H:Heiraten:rHD_rPP_rAN: a300:H:Bestrafung:rHD_rPP_rAN:

# %%
#60 Definieren der Variablen
gesep_1 ="h:KRANKHEIT:"
gesep_2 ="F:HEILMITTEL_besorgen:"
gesep_3 =""
gesep_4 =""

# %%
#61 Iteration über die Zeilen des DataFrames df
for i, gesuchte_label in enumerate(df.index_string):
    
    #62 Überprüfen, ob gesep_a-d in der aktuellen Zeile gesuchte_label vorhanden ist
    if gesep_1 in gesuchte_label or gesep_2 in gesuchte_label:# and gesep_3 not in gesuchte_label:# or gesep_4 in gesuchte_label):
        print(i, gesuchte_label)
        #63 Wenn gesep_1-4 gefunden wurde, markiere die entsprechende Zeile in der Spalte 'index_binar' als '1'
        #df.index_binar.iloc[i]='1' # Alte Variante
        df.loc[df.index[i], 'index_binar'] = '1'  # Sicherere Variante

#64 Speichern des aktualisierten DataFrames in einer CSV-Datei 'text_az.csv'
df.to_csv('text_az.csv', encoding='utf-8', index=False)
# Out:
# 1 a551:h:KRANKHEIT:rHH:
# 3 a551:F:HEILMITTEL_besorgen:rHH_fHD:
# 68 a551:h:KRANKHEIT:rHH:
# 70 a551:F:HEILMITTEL_besorgen:rHH_fHD:
# 72 a551:F:HEILMITTEL_besorgen:rHH_fHD:
# 99 a551:h:KRANKHEIT:rHH:
# 100 a551:F:HEILMITTEL_besorgen:rVB:
# 145 a314:h:KRANKHEIT:rHH_rVB: a314:F:HEILMITTEL_besorgen:rHH_rVB:
# 153 a314:F:HEILMITTEL_besorgen:rHD_rPP:
# 158 a551:h:KRANKHEIT:rHH:
# 161 a551:F:Gutes_Benehmen:rHD_rST: a551:H:Gutes_Benehmen:rHD_rST: a551:HF:Weiterverweisung_an_anderen_Stifter_oder_Helfer:rHD_rST: a551:F:HEILMITTEL_besorgen:rHD_rST:
# 162 a551:HF:Weiterverweisung_an_anderen_Stifter_oder_Helfer:rHD_rST: a551:F:HEILMITTEL_besorgen:rHD_rST:
# 178 a551:h:KRANKHEIT:rHH:
# 180 a551:F:HEILMITTEL_besorgen:rHD_rHH_fHD: a551:F:VEREINBARUNG:rHD_rHH_fHD:
# 212 a551:h:KRANKHEIT:rHH:
# 214 a551:F:HEILMITTEL_besorgen:rHH_fHD:

# %%
elim = "a551" # Datensätzen die diesen a Wert nicht haben aber b und/oder c schon, werden aus der Aggregatiodatei eliminiert 
#dadurch wird es verhindert, dass Datensetzen mit gleichen Inhalte nicht als negative Werte entgegengesetzt werden.

# Ursprünglichen DataFrame verarbeiten und speichern
df.to_csv('text_az.csv', encoding='utf-8', index=False)

# CSV-Datei erneut einlesen
df = pd.read_csv('text_az.csv', encoding='utf-8')

# Zeilen mit index_binar = 1 entfernen, wenn index_string nicht "a000" enthält
df = df[~((df['index_binar'] == 1) & (~df['index_string'].str.contains(elim, na=False)))]

# Gefilterten DataFrame erneut speichern
df.to_csv('text_az.csv', encoding='utf-8', index=False)

# %%
#65 Lesen der CSV-Datei 'text_az.csv' und Laden der Daten in ein Pandas DataFrame
df = pd.read_csv('text_az.csv',  encoding='utf-8')

#66 Extrahieren der Trainingsdaten X_train und der Labels y_train
X_train = df['inhalt']  # Inhalt der Texte
y_train = df['index_binar']  # Binäre Indikatoren

#67 Zählen der Vorkommen jeder Binärklasse in der Spalte 'index_binar'
indexliste = Counter(df.index_binar)

#68 Ausgabe der Anzahl der Vorkommen jeder Binärklasse
print(indexliste)
# Out:
# Counter({0: 242, 1: 14})

# %%
from sklearn.feature_extraction.text import TfidfVectorizer  
from sklearn.linear_model import LogisticRegression  
from sklearn.model_selection import GridSearchCV  
from sklearn.pipeline import make_pipeline  

#69 Definieren der Pipeline mit einem TF-IDF-Vektorisierer und einem logistischen Regressionsmodell
pipe = make_pipeline(TfidfVectorizer(min_df=2, stop_words=stpw, ngram_range=(1,1), norm=None), 
                     LogisticRegression())

#70 Definieren des Rastersuchgitters für den Regularisierungsparameter C des logistischen Regressionsmodells
param_grid = {'logisticregression__C': [0.001, 0.01, 0.1, 1, 10]}     

#71 Erstellen eines Rastersuchobjekts mit der Pipeline und dem Rastersuchgitter, das auf 5-facher Kreuzvalidierung basiert
grid = GridSearchCV(pipe, param_grid, cv=5)

#72 Anpassen der Rastersuche an die Trainingsdaten
grid.fit(X_train, y_train)

#73 Drucken des besten Scores aus der Kreuzvalidierung
print("Bester Score aus der Kreuzvalidierung: {:.2f}".format(grid.best_score_))
# Out:
# Bester Score aus der Kreuzvalidierung: 0.95

# %%
import numpy as np

#74 Extrahieren des TF-IDF-Vektorisierers aus dem besten Schätzschritt des Gittersuchlaufs
vectorizer = grid.best_estimator_.named_steps["tfidfvectorizer"]

#75 Ermitteln des maximalen TF-IDF-Werts für jedes Merkmal
max_value = vectorizer.transform(X_train).max(axis=0).toarray().ravel()

#76 Sortieren der Merkmale nach ihren TF-IDF-Werten
sorted_by_tfidf = max_value.argsort()

#77 Extrahieren der Merkmalsnamen aus dem Vektorisierer
feature_names = np.array(vectorizer.get_feature_names_out())
print("Gesamte Anzahl der Wörter: {}".format(len(vectorizer.vocabulary_)))
# Out:
# Gesamte Anzahl der Wörter: 1444

# %%
s_zahl = 200  #78 Anzahl der Merkmale, die in der Visualisierung dargestellt werden sollen

import matplotlib.pyplot as plt  
import mglearn

#79 Visualisieren der Koeffizienten des logistischen Regressionsmodells
mglearn.tools.visualize_coefficients(
    grid.best_estimator_.named_steps["logisticregression"].coef_,  #80 Koeffizienten des Modells
    feature_names,  n_top_features=s_zahl  #81 Merkmalsnamen und Anzahl der Merkmale, die visualisiert werden sollen
)

#82 Anzeigen des Gitters in der Visualisierung
plt.grid()

#83 Anzeigen der Visualisierung
plt.show()
#plt.savefig(s_zahl+'.png', dpi=80)

# %%
#84 Extrahieren der Koeffizienten aus dem logistischen Regressionsmodell
gio = grid.best_estimator_.named_steps["logisticregression"].coef_[0]

#85 Sortieren der Indizes der Koeffizienten nach ihrer Größe
n_top = np.argsort(gio)

#86 Sortieren der Koeffizienten nach ihrer Größe
z_top = np.sort(gio)

#87 Extrahieren der Top-Merkmale mit den höchsten Koeffizienten
text_pos = feature_names[n_top[-s_zahl:]]
zahl_pos = gio[n_top[-s_zahl:]]

#88 Extrahieren der Top-Merkmale mit den niedrigsten Koeffizienten
text_neg = feature_names[n_top[0:s_zahl]]
zahl_neg = gio[n_top[0:s_zahl]]

#89 Ausgabe der positiven Merkmale und ihrer Koeffizienten
print("Positive Merkmale:\n{}".format(text_pos))

#90 Ausgabe der negativen Merkmale und ihrer Koeffizienten
# print("Negative Merkmale:\n{}".format(text_neg))

#91 Ausgabe der Koeffizienten der positiven Merkmale
# print("Positive coef:\n{}".format(zahl_pos))

#92 Ausgabe der Koeffizienten der negativen Merkmale
# print("Negative coef:\n{}".format(zahl_neg))
# Out:
# Positive Merkmale:
# ['klueger' 'sprach' 'bat' 'wurde' 'prinzen' 'immer' 'fata' 'morgana'
#  'morgen' 'sieben' 'koenigssohn' 'jugend' 'schoene' 'land' 'nacht'
#  'vielleicht' 'weiss' 'zweite' 'aeltesten' 'schoenes' 'juengste' 'haus'
#  'hoerte' 'zeit' 'fand' 'wasser' 'wusste' 'lebte' 'darin' 'ganz' 'aepfel'
#  'vaters' 'gut' 'holen' 'augen' 'helfen' 'wol' 'fort' 'koenigs' 'koenne'
#  'schickte' 'traurig' 'endlich' 'ende' 'lebens' 'her' 'herrschte' 'pfau'
#  'koenigin' 'sehend' 'nahmen' 'kinder' 'beide' 'koepfe' 'gesagt' 'reise'
#  'alt' 'holte' 'reiche' 'geworden' 'wohnt' 'mitten' 'altes' 'gott'
#  'weinen' 'aufzusuchen' 'sandte' 'koennten' 'dafuer' 'weiblein' 'dritte'
#  'frage' 'bekommen' 'vergangen' 'gutes' 'irgend' 'greis' 'reihe' 'see'
#  'bestieg' 'gruesste' 'caesarius' 'wohnte' 'lieben' 'tat' 'bringt'
#  'grosses' 'fuelle' 'daher' 'wuerde' 'schicken' 'weinte' 'gebe' 'begab'
#  'krank' 'dachten' 'verlor' 'bekam' 'ruhe' 'bringe' 'vielen' 'beschloss'
#  'bestrichen' 'huette' 'unterwegs' 'sache' 'mache' 'gute' 'konnte'
#  'koestlichen' 'aelter' 'wanderten' 'merken' 'koenigreiche' 'siebenmal'
#  'entkommen' 'maechtiges' 'schweren' 'verstand' 'lebten' 'sagen' 'gewiss'
#  'verstrich' 'graf' 'ermordet' 'erhalten' 'berufen' 'konnten' 'mittlere'
#  'dank' 'fuehrt' 'heirathete' 'koenigstochter' 'lieb' 'grau' 'beantworten'
#  'tode' 'tapfer' 'armen' 'beriethen' 'arzt' 'wuerden' 'reichlich'
#  'verschaffen' 'frieden' 'ruestete' 'lieber' 'gepriesene' 'wirklich'
#  'schlafe' 'verheirathen' 'trauer' 'befallen' 'vergessen' 'allmaehlich'
#  'ueberlegte' 'wurden' 'guten' 'darinnen' 'klugen' 'wunderbare' 'blind'
#  'unglueck' 'solle' 'jahre' 'hand' 'welt' 'sohn' 'gerade' 'leben' 'vogel'
#  'gehen' 'tages' 'geld' 'aelteste' 'soehnen' 'federn' 'mittel' 'erzaehlte'
#  'gesicht' 'klug' 'alte' 'maenner' 'grossmutter' 'drueckte' 'waldes'
#  'wars' 'weit' 'ziehet' 'waesserlein' 'versehen' 'gesund' 'aerzte'
#  'weisen' 'krug' 'frau' 'drei' 'koenig' 'soehne' 'jenseit']

# %%
kfz = range(s_zahl)  # Erstellen einer Sequenz von Zahlen von 0 bis s_zahl-1
folgenum = 0  # Initialisieren des Zählers für die Folgennummer
pop = None  # Initialisierung der "pop"-Variable

# Iteration über die Zahlen in der Sequenz kfz
for x in kfz:
    folgenum += 1  # Inkrementieren der Folgennummer
    # Berechnen der Summe der Koeffizienten für das aktuelle Element in der Liste
    vollliste = zahl_pos[s_zahl - folgenum] + zahl_neg[s_zahl - folgenum]
    # Runden der Summe auf drei Dezimalstellen
    rundliste = round(vollliste, 3)
    # Ausgabe der gerundeten Summe und der aktuellen Zahl in der Sequenz
    print(rundliste, '-', x)
    
    # Bedingung, um zu prüfen, ob rundliste weniger als 0.001 ist
    if rundliste < 0.001:
        pop = x  # Setzen der "pop"-Variable auf den aktuellen Wert von x
        break  # Schleife beenden, da wir den kleinsten Wert von x gefunden haben

# Ausgabe des Ergebnisses
if pop is not None:
    print(f"Die 'pop'-Variable ist {pop}, da rundliste kleiner als 0.001 ist.")
else:
    print("Kein Wert gefunden, bei dem rundliste kleiner als 0.001 ist.")
# Out:
# 0.017 - 0
# 0.017 - 1
# 0.015 - 2
# 0.012 - 3
# 0.012 - 4
# 0.011 - 5
# 0.01 - 6
# 0.01 - 7
# 0.009 - 8
# 0.008 - 9
# 0.008 - 10
# 0.008 - 11
# 0.008 - 12
# 0.008 - 13
# 0.008 - 14
# 0.007 - 15
# 0.007 - 16
# 0.007 - 17
# 0.007 - 18
# 0.007 - 19
# 0.006 - 20
# 0.006 - 21
# 0.005 - 22
# 0.005 - 23
# 0.005 - 24
# 0.005 - 25
# 0.005 - 26
# 0.004 - 27
# 0.004 - 28
# 0.004 - 29
# 0.004 - 30
# 0.004 - 31
# 0.004 - 32
# 0.004 - 33
# 0.004 - 34
# 0.003 - 35
# 0.003 - 36
# 0.003 - 37
# 0.003 - 38
# 0.003 - 39
# 0.003 - 40
# 0.003 - 41
# 0.003 - 42
# 0.003 - 43
# 0.003 - 44
# 0.003 - 45
# 0.003 - 46
# 0.003 - 47
# 0.003 - 48
# 0.003 - 49
# 0.003 - 50
# 0.003 - 51
# 0.003 - 52
# 0.003 - 53
# 0.003 - 54
# 0.003 - 55
# 0.003 - 56
# 0.003 - 57
# 0.003 - 58
# 0.003 - 59
# 0.003 - 60
# 0.003 - 61
# 0.003 - 62
# 0.003 - 63
# 0.002 - 64
# 0.002 - 65
# 0.002 - 66
# 0.002 - 67
# 0.002 - 68
# 0.002 - 69
# 0.002 - 70
# 0.002 - 71
# 0.002 - 72
# 0.002 - 73
# 0.002 - 74
# 0.002 - 75
# 0.002 - 76
# 0.002 - 77
# 0.002 - 78
# 0.002 - 79
# 0.002 - 80
# 0.002 - 81
# 0.002 - 82
# 0.002 - 83
# 0.002 - 84
# 0.002 - 85
# 0.002 - 86
# 0.002 - 87
# 0.002 - 88
# 0.002 - 89
# 0.002 - 90
# 0.002 - 91
# 0.002 - 92
# 0.002 - 93
# 0.002 - 94
# 0.002 - 95
# 0.002 - 96
# 0.002 - 97
# 0.002 - 98
# 0.002 - 99
# 0.002 - 100
# 0.001 - 101
# 0.001 - 102
# 0.001 - 103
# 0.001 - 104
# 0.001 - 105
# 0.001 - 106
# 0.001 - 107
# 0.001 - 108
# 0.001 - 109
# 0.001 - 110
# 0.001 - 111
# 0.001 - 112
# 0.001 - 113
# 0.001 - 114
# 0.001 - 115
# 0.001 - 116
# 0.001 - 117
# 0.001 - 118
# 0.001 - 119
# 0.001 - 120
# 0.001 - 121
# 0.001 - 122
# 0.001 - 123
# 0.001 - 124
# 0.001 - 125
# 0.001 - 126
# 0.001 - 127
# 0.001 - 128
# 0.001 - 129
# 0.001 - 130
# 0.001 - 131
# 0.001 - 132
# 0.001 - 133
# 0.0 - 134
# Die 'pop'-Variable ist 134, da rundliste kleiner als 0.001 ist.

# %%
#100 Schwelenwert bestimmen
sw = pop-1
print(sw)
# Out:
# 133

# %%
filename ='!_neu'  #101 Der Dateiname für die CSV-Datei (ohne Erweiterung)
tit = (text_pos[s_zahl-sw:s_zahl])  #102 Die Titelzeile, die geschrieben werden soll

#103 Öffnen der CSV-Datei zum Schreiben ('wt' für Schreiben im Textmodus)
with open (filename+'.csv', 'wt', encoding='utf-8') as f:
    writer = csv.writer(f)  #85 Initialisieren des CSV-Schreibers
    writer.writerow(tit)  #86 Schreiben der Titelzeile in die CSV-Datei

# %% [markdown]
# ### Messdaten aufbereiten

# %%
import xml.etree.ElementTree as ET  # Importieren der ElementTree-Bibliothek zum Parsen von XML

# XML-Daten laden
tree = ET.parse('Textkorpus.xml')
root_node = tree.getroot()

# Namespace definieren
NS = {'tei': 'http://www.tei-c.org/ns/1.0'}

# Filtereinstellung für das Attribut `@ident` (kann leer sein)
# filter_ident = ""  # z. B. input("Bitte geben Sie das Attribut 'ident' an (z.B. 'kat'): ").strip()

# Variable für die gesammelten Märchendaten
maerchen = ""

# Iteration durch die XML-Daten
for corp in root_node.findall(".//tei:teiCorpus", NS):
    if "" in corp.attrib.get("n", "") or "xtk" in corp.attrib.get("n", ""):
        for tei in corp.findall("tei:TEI", NS):
            # Filter basierend auf `@ident` oder bei leerem `filter_ident`
#             language = tei.find(".//tei:teiHeader//tei:langUsage/tei:language", NS)
#             if language is not None:
#                 ident_value = language.attrib.get('ident', '')
#                 if filter_ident == "" or ident_value == filter_ident:
                    for ganze in tei.findall(".//tei:text", NS):
                        quelle = ganze.attrib.get('{http://www.w3.org/XML/1998/namespace}id', '')
                        for body in ganze.findall(".//tei:body", NS):
                            for absatz in body.findall(".//tei:p", NS):
                                for phrase in absatz.findall(".//tei:seg", NS):
                                    # Labels extrahieren
                                    labela = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/a}ana', 'N/A')
                                    labelb1 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/b1}ana', 'N/A')
                                    labelb2 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/b2}ana', 'N/A')
                                    labelb3 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/b3}ana', 'N/A')
                                    labelb4 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/b4}ana', 'N/A')
                                    labelb5 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/b5}ana', 'N/A')
                                    labelc1 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/c1}ana', 'N/A')
                                    labelc2 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/c2}ana', 'N/A')
                                    labelc3 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/c3}ana', 'N/A')
                                    labelc4 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/c4}ana', 'N/A')
                                    labelc5 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/c5}ana', 'N/A')
                                    labeld = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/d}ana', 'N/A')
                                    inhalt = (phrase.text.lower().strip()
                                              .replace('|', '').replace(':', '').replace("ä", "ae")
                                              .replace("ü", "ue").replace("ö", "oe").replace("ß", "ss")
                                              .replace(",", "").replace("\n", " ").replace("'", "")
                                              .replace("…", "").replace('"', "").replace("*", "")
                                              .replace("(", "").replace(")", "").replace("-", "")
                                              .replace("]", "").replace("[", "").replace(".", "")
                                              .replace("?", "").replace("!", "").replace("„", "")
                                              .replace("+", "").replace("=", "").replace("_", "")
                                              .replace("­", "").replace('“', "").replace('”', "")
                                              .replace(";", "").replace('~', "").replace('`', "")
                                              .replace("«","").replace("»",""))
                                    # Bedingung: labela beginnt mit 'a' und labelb1 ist nicht 'N/A'
                                    if labelb1.startswith('N'):
                                        # Märchendaten sammeln
                                        maerchen += (quelle + ',' + labela + ',' + labelb1 + ',' + labelc1 + ',' +
                                                     labelb2 + ',' + labelc2 + ',' + labelb3 + ',' + labelc3 + ',' +
                                                     labelb4 + ',' + labelc4 + ',' + labelb5 + ',' + labelc5 + ',' +
                                                     labeld + ',' + inhalt + ',0' + '\n')

# Ergebnisse in eine CSV-Datei schreiben
with open("text.csv", 'w', encoding='utf-8') as f:
    # Kopfzeile schreiben
    f.write('quelle,labela,labelb1,labelc1,labelb2,labelc2,labelb3,labelc3,labelb4,labelc4,labelb5,labelc5,labeld,inhalt,index_binar')
    f.write('\n')
    # Gesammelte Märchendaten schreiben
    f.write(maerchen)

print(f"Die Märchendaten  wurden in 'text.csv' gespeichert.")
# Out:
# Die Märchendaten  wurden in 'text.csv' gespeichert.

# %%
#118 Öffnen der CSV-Datei im Lesemodus und Lesen ihres Inhalts
with open(filename+'.csv', 'r', encoding='utf-8') as file:
    file_contents = file.read().replace(",", " ").replace("\n", "")  #119 Entfernen von Kommas und Zeilenumbrüchen

#120 Zusammenstellen des neuen Inhalts mit dem Dateinamen und zusätzlichen Metadaten
frt_contents = filename+',N,N,N,N,N,N,N,N,N,N,N,N'+','+file_contents+',0'

#121 Löschen der ursprünglichen CSV-Datei
import os 
os.remove(filename+'.csv')

# %%
row = [frt_contents]  #122 Erstellen einer neuen Zeile mit dem zusammengestellten Inhalt

#123 Öffnen der CSV-Datei im Lesemodus und Lesen der vorhandenen Zeilen
with open("text.csv", 'r', encoding='utf-8') as readFile:
    rd = csv.reader(readFile)  #124 Initialisieren des CSV-Lesers
    lines = list(rd)  #125 Lesen der Zeilen und Konvertieren in eine Liste

    #126 Einfügen der neuen Zeile an der zweiten Position in die Liste der Zeilen
    lines.insert(1, row)

#127 Öffnen der CSV-Datei im Schreibmodus und Schreiben der aktualisierten Zeilen
with open("text.csv", 'wt', newline='', encoding='utf-8') as writeFile:
    wt = csv.writer(writeFile)  #128 Initialisieren des CSV-Schreibers
    wt.writerows(lines)  #129 Schreiben der Zeilen in die Datei

#130 Öffnen der ursprünglichen und neuen CSV-Dateien zum Lesen bzw. Schreiben
fin = open('text.csv', 'r', encoding='utf-8')
fout = open('text_reich.csv', "wt", encoding='utf-8')

#131 Iteration über die Zeilen der ursprünglichen CSV-Datei
for kfz in fin:
    #132 Schreiben der Zeile in die neue Datei mit Entfernung bestimmter Zeichenfolgen
    fout.write(kfz.replace('"', ''))
#133 Schließen beider Dateien
fin.close()
fout.close()

# %%
#134 Funktion für die Beseitigung der leeren Datensätzen
def delete_records_with_empty_field(file_path, field_name):
    
    #135 Öffnen der CSV-Datei im Lese-Modus
    with open(file_path,  'r', encoding="utf-8") as file:
        #136 Lesen der Daten als Liste von Dictionaries
        reader = csv.DictReader(file)
        rows = list(reader)

    #137 Überprüfen, ob das Feld in den Daten leer ist
    filtered_rows = [row for row in rows if row[field_name]]

    #138 Öffnen der CSV-Datei im Schreibmodus und Schreiben der verbleibenden Datensätze
    with open(file_path, 'w', encoding="utf-8", newline='') as file:
        writer = csv.DictWriter(file, fieldnames=reader.fieldnames)
        writer.writeheader()
        writer.writerows(filtered_rows)

#139 Beispielaufruf der Funktion
file_path = 'text_reich.csv'  #140 Passe den Pfad zu deiner CSV-Datei an
field_name = 'inhalt'  #142 Passe den Namen des Feldes an, das überprüft werden soll
delete_records_with_empty_field(file_path, field_name)

# %%
t_corpus = []  #143 Eine leere Liste zum Speichern der Textdaten
df = pd.read_csv('text_reich.csv', encoding='utf-8')  #144 Einlesen der CSV-Datei in ein Pandas DataFrame
file = 'text_reich.csv'  #145 Der Dateiname der CSV-Datei

#146 Öffnen der CSV-Datei im Lesemodus und Extrahieren der Textdaten
with open(file, "rt", encoding='utf-8') as maerchen:
    maercho = df.inhalt  #147 Extrahieren der Spalte "inhalt" aus dem DataFrame
    reader = csv.reader(maercho)  #148 Initialisieren des CSV-Lesers
    for row in reader:
        lst = str(row)  #149 Konvertieren der gelesenen Zeile in eine Zeichenfolge
        t_corpus.append(lst)  #150 Hinzufügen der Zeichenfolge zur Liste der Textdaten

# %% [markdown]
# ### Vorhersage

# %%
# from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

#162 Initialisieren des TF-IDF-Vektorisierers mit bestimmten Parametern
vectorizer = TfidfVectorizer(analyzer='word', ngram_range=(1,1), 
                             min_df=1, stop_words=stpw)

#163 Erstellen des Vokabulars aus den Textdaten mit dem TF-IDF-Vektorisierer
vocabulary = vectorizer.fit_transform(t_corpus)

#164 Funktion zur Suche nach ähnlichen Dokumenten basierend auf der Kosinusähnlichkeitsmetrik
def find_similar(vocabulary, index, top_n=-1):
    #165 Berechnen der Kosinusähnlichkeitswerte zwischen dem ausgewählten Dokument und allen anderen Dokumenten
    similarities = cosine_similarity(vocabulary[index:index+1], vocabulary).flatten()
    #166 Sortieren der Dokumente basierend auf den Kosinusähnlichkeitswerten in absteigender Reihenfolge
    related_docs_indices = [i for i in similarities.argsort()[::-1] if i != index]
    #167 Auswahl der Top-n ähnlichsten Dokumente und Rückgabe ihrer Indizes und Kosinusähnlichkeitswerte
    return [(index, similarities[index]) for index in related_docs_indices][:top_n]

#168 Die TF-IDF-Vektoren für die Textdaten können über `vocabulary` abgerufen werden
# print(vocabulary)

# %%
n_te = 0  #169 Index des ersten Dokuments
inhalt = df.inhalt[n_te]
print(inhalt)  #170 Ausgabe des Inhalts des ersten Dokuments

#with open(gesep_1.replace(':','')+'.txt','w', encoding="utf-8") as file:
    #file.write(inhalt)
# Out:
